# %%
import tensorflow as tf
from note_sequence_io import *
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
sess = tf.Session()

# %%
note_sequence_dir = 'datasets/Wikifonia.tfrecord'
dataset = tf.data.TFRecordDataset(note_sequence_dir)

# %%
note_sequence_dataset = note_sequence_record_iterator(note_sequence_dir)
# note_sequence_dataset 是一个 python generator对象
len(list(note_sequence_dataset))
# 这是一种获取长度的简单方式，但是由于generator是一次性迭代的，所以使用需要重新声明一次
note_sequence_dataset = note_sequence_record_iterator(note_sequence_dir)

# %%
'''
以下这种方式可以对note_sequence进行遍历，输出其中信息

可以看到，note_sequence中包含了文件名，目录名，id，调性，节奏，音符，和音乐记号等信息，
非常全面。
'''
cnt = 0
for i in note_sequence_dataset:
    cnt+=1
    if(cnt<=1):
        print(i)
for i in note_sequence_dataset:
    cnt+=1
    if(cnt<=1):
        print(i)
# Out:
# id: "/id/musicxml/Wikifonia/8707c9d94115cdbb8d585f8d3bd2dbbf2ec6b7f7"
# filename: "Walter Kent, Nat Burton - The White Cliffs of Dover.mxl"
# collection_name: "Wikifonia"
# ticks_per_quarter: 220
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# key_signatures {
#   key: D_SHARP
# }
# tempos {
#   qpm: 120.0
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 5
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 1.5
#   end_time: 2.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 5
#   voice: 1
# }
# notes {
#   pitch: 75
#   velocity: 64
#   start_time: 2.0
#   end_time: 3.0
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 5
#   voice: 1
# }
# notes {
#   pitch: 75
#   velocity: 64
#   start_time: 3.0
#   end_time: 4.0
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 5
#   voice: 1
# }
# notes {
# ...
